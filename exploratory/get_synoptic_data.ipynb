# %%
import matplotlib.pyplot as plt
from datetime import datetime
import synoptic.services as ss
from synoptic.services import stations_timeseries

# Use snyopticPy library to search and download data from Snyoptic Data.

# ---------------------------------------------------------------------

# Request a single station by listing the station id.  
# Station ID can be found at Mesowest or by searcing by radius (below)
#params = dict(
#    stid='USDS-3',
#    vars=['air_temp', 'dew_point_temperature'],
#    start=datetime(2020, 8, 15),
#    end=datetime(2020, 8, 18)
#)
#data = stations_timeseries(verbose='HIDE', **params)
# ---------------------------------------------------------------------

# Obtain a list of stations & data within the specified radius.
lat = 42.0
lon = -93.7

radius = [lat, lon, 5] # lat, lon, radius in km.
params = dict(
    radius=radius,
    vars=['air_temp', 'dew_point_temperature'],
    start=datetime(2020, 8, 15),
    end=datetime(2020, 8, 18)
)
data = stations_timeseries(verbose='HIDE', **params)
data
# ---------------------------------------------------------------------
# Out:
# /opt/miniconda3/envs/hydrosat-analytics-python/lib/python3.9/site-packages/synoptic/accessors.py:28: UserWarning: map making not available without Brian's cartopy_tools
#   warnings.warn("map making not available without Brian's cartopy_tools")
#  🚚💨 Speedy Delivery from Synoptic API [timeseries]: https://api.synopticdata.com/v2/stations/timeseries?radius=42.0,-93.7,5&vars=air_temp,dew_point_temperature&start=202008150000&end=202008180000&token=🙈HIDDEN
#
# Returned [6] stations. ['KAMW', 'AMMI4', 'UP757', 'COOPAMSI4', 'AMFI4', 'BOOI4']
# [                           air_temp  dew_point_temperature_set_1  \
#  date_time
#  2020-08-15 00:00:00+00:00      28.0                          NaN
#  2020-08-15 00:05:00+00:00      28.0                          NaN
#  2020-08-15 00:10:00+00:00      28.0                          NaN
#  2020-08-15 00:15:00+00:00      28.0                          NaN
#  2020-08-15 00:20:00+00:00      28.0                          NaN
# ...
