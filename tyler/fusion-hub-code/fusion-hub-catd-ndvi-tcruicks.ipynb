# %% [markdown]
# # Calculate CATD and NDVI

# %% [markdown]
# #### Computes CATD and NDVI for a point location.
# 1. Download images from STAC.
# 2. Define point location.

# %%
import json
import requests
import pystac
from pystac_client import Client
from pprint import pprint

from botocore.exceptions import ClientError
from shapely.geometry import box, mapping, Point, Polygon

from pyproj.crs import CRS
import pandas as pd
import geopandas as gpd

import xarray as xr
import rioxarray as rxr
import rasterio as rio

from matplotlib import pyplot as plt
import numpy as np

from FH_Hydrosat import FH_StackedDataset
from FH_Hydrosat import FH_Hydrosat

import os
import base64
from datetime import datetime
from datetime import date

# %% [markdown]
# If you see `ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed`, do not fret, and proceed.

# %% [markdown]
# ### Logging in to the Fusion database.
#
# This next cell opens a file `creds.json` which you will need to create in the same directory
# as the notebook. The format of the file should be:
#
# {
# "username":"your_username",
# "password":"your_password"
# }
#
# and you have updated with your username and password.

# %%
with open('creds.json') as f:
    creds = json.loads(f.read())

# Endecode the `username:password` combination 
# and use it to authorize access to the STAC API given by the `cat_url` 
# endpoint.userpass = f"{creds['username']}:{creds['password']}"
userpass = f"{creds['username']}:{creds['password']}"
b64 = base64.b64encode(userpass.encode()).decode()
headers = {'Authorization':'Basic ' + b64}

cat_url = 'https://fusion-stac.hydrosat.com'
catalog = Client.open(cat_url, headers)

# %% [markdown]
# ### Set variables for STAC search.
# We'll search for data in the `starfm_predictions_modis_landsat` and `pydms_sharpened_landsat` collections which intersect a point location between a start date and an end date and print out the number of items.

# %%
# Specifiy location and time frame for image download.
from distutils.command import sdist

site_name = 'ames'
lat = 42.0    # Edit this. ***************
lon = -93.7   # Edit this. ***************
geom = {'type': 'Point', 'coordinates': [lon, lat]} 

# Specify dates & hour for LST analysis.
start = "2020-04-01"  # Edit this. ***************
end = "2020-10-30"  # Edit this. ***************
hr = "00:00:00"  # Edit this. ***************

# LST collections to search.
lst_collections = ["starfm_predictions_modis_landsat", "pydms_sharpened_landsat"]
# NDVI collections to search.
ndvi_collections = ["prepped_inputs_s2"]

# We need the total num of days for the analysis to get hrrr data.
f = start.split("-")
l = end.split("-")

f_dt = date(int(f[0]), int(f[1]), int(f[2]))  
l_dt = date(int(l[0]), int(l[1]), int(l[2]))  
num_days = (l_dt - f_dt)
num_days = num_days.days

# Need to do some formating for various requirements.
hr_form = "T{}Z".format(hr)
start_date = start + hr_form
end_date = end + hr_form

# %% [markdown]
# ### Search for available LST tiles.

# %%
search = catalog.search(
    collections = lst_collections,
    intersects = geom,
    datetime = [start_date, end_date],
    max_items = 500
)

#items = list(search.items()) # for pystac-client >= 0.4.0
items = list(search.get_all_items()) # for pystac-client < 0.4.0
items.reverse() # make the results ascending in time

num_tiles = len(items)
print ("Number of days to process: {}".format(num_days))
print ("Number of fusion tiles available: {}".format(num_tiles))
# Out:
# Number of days to process: 212
# Number of fusion tiles available: 180

# %% [markdown]
# ### Search for available Surface Reflectance (NDVI) tile for point location.

# %%
bbox = [-93.68802, 42.00908, -93.68783, 41.991]
collection = ["prepped_inputs_s2"]

search = catalog.search(
    collections = ndvi_collections,
    intersects=geom,
    datetime = [start_date, end_date],
    max_items = 500
)

s2_items = search.get_all_items()
print(f'Number of prepped_inputs_s2 items: {len(s2_items)}')
# Out:
# Number of prepped_inputs_s2 items: 23

# %% [markdown]
# ### Create two functions to create AOI polygon for clipping to define a smaller dataarry.
# The `DataArray` is quite large if we try to access all of the data. For ease of computation, we'll subset the `DataArray` by a polygon, which will be generated by creating a rectangular buffer around the point location by 1km on either side.

# %%
def create_clip_polygon(geom, ds):
    """
    Create a polygon that we will use for clipping the big dataset.

    Parameters:
    ----------
    geom: dict
        Dictionary of lat and lon of center point of AOI.

    Returns:
    -------
    poly: dataframe
        Contains geometry of a square to be used for clipping.
    """
    # Using the point coords defined earlier, create a df with the point geometry.
    p_geom = Point(geom['coordinates'][0], geom['coordinates'][1])
    point_df = gpd.GeoDataFrame({'geometry':[p_geom]}, crs=CRS.from_epsg(4326))

    # Define a buffer size (for each side of the point.
    # Reproject the point df and create the new polygon.
    raster_crs = CRS.from_wkt(ds.spatial_ref.crs_wkt)
    buffer_dist = 1000 # 1km in local UTM zone

    # create a square buffer
    poly_df = point_df.to_crs(raster_crs).buffer(buffer_dist, cap_style = 3) 

    return(poly_df)

# %%
def clip(poly_df, ds):
    ''' 
    Clip the big stacked dataset.

    Parameters: 
    -----------
    poly_df: geodataframe

    Returns:
    -------
    ds_clip: dataset
        This is our clipped, smaller dataset.
    '''
    # Want to create a new StackedDataset object using a smaller clipped
    # version of the big whole image dataset.
    clipped = FH_StackedDataset(ds.rio.clip(poly_df.geometry))
    clip_ds = clipped.ds  #*************** what is this?
    
    return(clip_ds)

# %% [markdown]
# ### Download and stack full-size LST image tiles.
# This will allow facetgrid plotting.  If you dont want to plot the tiles then skip to the next code cell.

# %%
from FH_Hydrosat import FH_Hydrosat

# Having funny unpredictable behavior so 
# want to be sure these are clean da each time cel is run.
ds = xr.DataArray()
stacked_lst_da = xr.DataArray()

res = FH_Hydrosat(items[:num_tiles])

print ("Time 1:{}".format(datetime.now()))
stacked_res = res.stack()
print ("Start 2:{}".format(datetime.now()))

stacked_res.ds.sortby('time')
# Sort the dataset by time.
ds = stacked_res.ds.sortby('time')

# Create polygon AOI.
clip_poly_df = create_clip_polygon(geom, ds)
# Use AOI to clip raster dwon to size.
stacked_lst_da = clip(clip_poly_df, ds)
# Out:
# Time 1:2023-04-24 11:12:23.544887
# Start 2:2023-04-24 11:13:41.523503

# %%
# Can I get max, mean, min lst from stacked da?

#min = stacked_lst_da.isel(band=0).min().plot(linestyle='--', marker='o', c='m', label='Point location', figsize=(8,5))
min = stacked_lst_da.min(dim='time')

#plt.show()
stacked_lst_da.isel(band=0).min(dim='time').plot()

# %% [markdown]
# ### Download and extract LST data for a point.

# %%
# Set the point for time-series extraction.
point_wgs84 = Point(box(*bbox).centroid.x, box(*bbox).centroid.y)

lst_res = FH_Hydrosat(items[:num_tiles])
lst_k = lst_res.point_time_series_from_items(point_wgs84, tol=40, nproc=6, band=0) 
lst_dt = lst_res.datetime
type(lst_k)
# Out:
# using 6 processes to sample 180 assets
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# list

# %% [markdown]
# ### Download and extract surface reflectance (NDVI) data for a point.
# - Download only the band assets we need for NDVI.

# %%
# sample the sentinel2 items
s2_res = FH_Hydrosat(s2_items, asset='surface_reflectance')

# Set the point for time-series extraction.
point_wgs84 = Point(box(*bbox).centroid.x, box(*bbox).centroid.y)

# Extract time-series for RED and NIR bands.
s2_red_ts = s2_res.point_time_series_from_items(point_wgs84, tol=40, nproc=6, band=2) 
s2_nir_ts = s2_res.point_time_series_from_items(point_wgs84, tol=40, nproc=6, band=6) 
s2_dt = s2_res.datetime
# Out:
# using 6 processes to sample 23 assets
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# using 6 processes to sample 23 assets
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd
# /Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/FH_Hydrosat.py:21: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# ### Plot a time series of the point and mean LST in the image.

# %%
centroid = clip_poly_df.geometry[0].centroid
set_x, set_y, pixtype = (centroid.x, centroid.y, 'Center Pixel') 

# Plot two time-series:
#    The LST from the point.  Same as above.
#    The mean LST from the whole image.
ax = (stacked_lst_da
      .isel(band=0)
      .sel(x=set_x, y=set_y, method='nearest', tolerance=20)
      .plot(linestyle='--', marker='o', c='m', label='Point location', figsize=(8,5))
      )

ax = (stacked_lst_da
      .isel(band=0)
      .mean(dim=('x', 'y'))
      .plot(linestyle='--', marker='o', c='b', label='Area mean')
      )

plt.title(f'time series for {pixtype} pixel')
plt.legend()
plt.grid(True)
plt.ylabel('Fused LST [K]')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Drop files with data less than 50% coverage
# Sometimes the data will have low coverage due to cloud cover or invalid pixels in the input data products. Let's remove them from the dataset using the `remove_below_data_perc()` function, plot them, and create an animation.

# %%
# First, stacked_lst_da was not created as an object of FH_StackedDataset.
# We'll make it an object here (or try).
LST_filtered_test = FH_StackedDataset(stacked_lst_da)

# %%
# to switch back and allow xarray plots
# %matplotlib inline 

LST_filtered = FH_StackedDataset(LST_filtered_test.remove_below_data_perc(LST_filtered_test.ds, 0.5))
#ax = LST_filtered.ds.plot(x='x', y='y', col='time', col_wrap=5)
#ax.set_xlabels('Easting [m]')
#ax.set_ylabels('Northing [m]')
#plt.show()

# %% [markdown]
# #### Function for downloading HRRR two meter temperature.

# %%
def get_hrrr_point_data(lat, lon, start, days):
    ''' 
    Fetch met data from the HRRR model system.
    Herbie package needs to be installed:
    https://herbie.readthedocs.io/en/stable/

    Parameters:
    ----------
    lat, lon: float
        Coords from which to pull grid cell data. 
    start: str
        This is the start date for which data will be retrieved.
    days: int
        Number of days of data to retrieve.

    Return:
    -------
    ds_point: xarray dataset
        Met data for specified point.
    '''
    import pandas
    from herbie import FastHerbie

    # Create a range of dates
    DATES = pandas.date_range(
        start=start,
        periods=num_days,
        freq="1D",
    )

    # Define forecast lead time (or analysis).
    fxx = range(0, 1)

    # -----------------------------------------------
    # For long time-series analyses
    # -----------------------------------------------
    FH = FastHerbie(DATES, model="hrrr", fxx=fxx)
    FH.download("TMP:2 m")
    ds = FH.xarray("TMP:2 m", remove_grib=False)
    # -----------------------------------------------
    # For real-time fetching of HRRR data.
    # -----------------------------------------------
    # Make FastHerbie Object.
    # FH = FastHerbie(DATES, model="hrrr", fxx=fxx)
    # Read a subset of the data with xarray.
    # ds = FH.xarray("TMP:2 m", remove_grib=False)
    # -----------------------------------------------

    # Get data values nearest single point
    ds_point = ds.herbie.nearest_points(points=(lon, lat))
   
    return (ds_point)

# %% [markdown]
# ### Function for filling in missing dates in a dataframe.

# %%
def fill_in_missing_dates(sdt, ldt, df, date_col_name = 'date',fill_val = np.nan,date_format='%Y-%m-%d'):
    
    df.set_index(date_col_name,drop=True,inplace=True)
    df.index = pd.to_datetime(df.index, format = date_format)
    idx = pd.date_range(sdt, ldt)

    df=df.reindex(idx,fill_value=fill_val)

    df[date_col_name] = df.index
    df.reset_index(drop=True,inplace=True)

    return df

# %% [markdown]
# #### Get HRRR 2-meter Temperature & create a dataframe for it.

# %%
import get_hrrr as hrrr

# Get hrrr data for plotting with lst.

# Need to do a little formatting of the time given to the
# get hrr function.  Format needs to be '2020-08-01 00:00'.
hr_hrrr = hr.split(":")
start_hrrr = "{} {}:{}".format(start, hr_hrrr[0], hr_hrrr[1])
temp_2m_ds = get_hrrr_point_data(lat, lon, start_hrrr, num_days)

# Convert to dataframe and clean it up.
# Get a dataset of point hrrr and convert to dataframe for easier use.
temp_2m_df = temp_2m_ds.to_dataframe()

# Clean up df and drop uneeded columns.
drop_cols = ['metpy_crs', 'gribfile_projection', 'y', 'x', 'point']
temp_2m_df.reset_index(inplace=True)
temp_2m_df.drop(drop_cols, axis=1, inplace=True)

# Rename some of the cols
temp_2m_df.rename(columns = {'latitude':"hrrr_lat", 'longitude':"hrrr_lon"}, inplace=True)
temp_2m_df.rename(columns = {'point_latitude':"hrrr_pnt_lat", 'point_latitude':"hrrr_pnt_lon"}, inplace=True)

# Make date consistent in format.
temp_2m_df['date'] = pd.to_datetime(temp_2m_df['time'].dt.date)
# Out:
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200401]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200402]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200403]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200404]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200405]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200406]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200407]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200408]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200409]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200410]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200411]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200412]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200413]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200414]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200415]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200416]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200417]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200418]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200419]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200420]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200421]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200422]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200423]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200424]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200425]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200426]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200427]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200428]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200429]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200430]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200501]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200502]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200503]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200504]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200505]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200506]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200507]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200508]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200509]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200510]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200511]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200512]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200513]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200514]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200515]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200516]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200517]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200518]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200519]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200520]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200521]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200522]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200523]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200524]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200525]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200526]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200527]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200528]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200529]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200530]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200531]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200601]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200602]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200603]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200604]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200605]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200606]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200607]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200608]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200609]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200610]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200611]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200612]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200613]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200614]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200615]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200616]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200617]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200618]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200619]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200620]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200621]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200622]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200623]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200624]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200625]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200626]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200627]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200628]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200629]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200630]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200701]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200702]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200703]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200704]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200705]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200706]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200707]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200708]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200709]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200710]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200711]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200712]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200713]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200714]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200715]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200716]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200717]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200718]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200719]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200720]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200721]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200722]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200723]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200724]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200725]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200726]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200727]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200728]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200729]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200730]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200731]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200801]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200802]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200803]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200804]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200805]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200806]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200807]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200808]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200809]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200810]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200811]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200812]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200813]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200814]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200815]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200816]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200817]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200818]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200819]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200820]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200821]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200822]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200823]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200824]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200825]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200826]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200827]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200828]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200829]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200830]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200831]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200901]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200902]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200903]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200904]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200905]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200906]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200907]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200908]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200909]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200910]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200911]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200912]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200913]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200914]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200915]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200916]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200917]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200918]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200919]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200920]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200921]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200922]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200923]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200924]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200925]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200926]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200927]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200928]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200929]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20200930]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201001]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201002]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201003]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201004]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201005]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201006]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201007]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201008]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201009]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201010]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201011]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201012]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201013]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201014]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201015]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201016]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201017]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201018]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201019]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201020]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201021]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201022]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201023]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201024]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201025]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201026]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201027]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201028]
# 👨🏻‍🏭 Created directory: [/Users/tylercruickshank/earth-analytics/ea-assignments/ea-lst-capstone/tyler/fusion-hub-code/hrrr/20201029]

# %% [markdown]
# #### Get LST from centerpoint of AOI & create a dataframe for it.

# %%
# Select lst for a point in the AOI domain.
# lst_fil_ds = LST_filtered.ds.isel(band=0).sel(x=set_x, y=set_y, method='nearest', tolerance=20)
lst_fil_ds = stacked_lst_da.isel(band=0).sel(x=set_x, y=set_y, method='nearest', tolerance=20)

# Convert the output to a dataframe.
lst_fil_df = lst_fil_ds.to_dataframe(name='lst')

# Set the index/data to a date format that will be consistent with reindexing below given
# a range of dates.
lst_fil_df.index = pd.to_datetime(lst_fil_df.index).date

# Clean up df and drop uneeded columns.
drop_cols = ['spatial_ref']
lst_fil_df.drop(drop_cols, axis=1, inplace=True)
lst_fil_df.rename(columns = {'x':"x_lst", 'y':"y_lst", 'band':"lst_band"}, inplace=True)

# Fill in any dates where there is missing LST and then reset the index.
# LST sometimes will have days when no data was retrieved.
lst_df = lst_fil_df.reindex(pd.date_range(start, end, freq="D")).reset_index()
# Out:
# ERROR 1: Request for 346275-352174 failed with response_code=403
# ERROR 1: Request for 362976-368875 failed with response_code=403
# ERROR 1: Request for 379677-385576 failed with response_code=403
# ERROR 1: Request for 396378-402277 failed with response_code=403
# ERROR 1: Request for 413079-418978 failed with response_code=403
# ERROR 1: Request for 429780-435679 failed with response_code=403
# ERROR 1: Request for 446481-452380 failed with response_code=403
# ERROR 1: Request for 463182-469081 failed with response_code=403
# ERROR 1: Request for 346275-352174 failed with response_code=403
# ERROR 1: Request for 362976-368875 failed with response_code=403
# ERROR 1: Request for 379677-385576 failed with response_code=403
# ERROR 1: Request for 396378-402277 failed with response_code=403
# ERROR 1: Request for 413079-418978 failed with response_code=403
# ERROR 1: Request for 429780-435679 failed with response_code=403
# ERROR 1: Request for 446481-452380 failed with response_code=403
# ERROR 1: Request for 463182-469081 failed with response_code=403
# ERROR 1: TIFFFillTile:0: Invalid tile byte count, tile 184
# ERROR 1: TIFFReadEncodedTile() failed.
# ERROR 1: IReadBlock failed at X offset 8, Y offset 8: TIFFReadEncodedTile() failed.
# ERROR 1: Request for 59694248-61101602 failed with response_code=403
# ERROR 1: Request for 63473171-64892995 failed with response_code=403
# ERROR 1: Request for 67256709-68670129 failed with response_code=403
# ERROR 1: Request for 71025244-72434372 failed with response_code=403
# ERROR 1: Request for 74804719-76211192 failed with response_code=403
# ERROR 1: Request for 78586072-79992814 failed with response_code=403
# ERROR 1: Request for 82370769-83780005 failed with response_code=403
# ERROR 1: Request for 86148315-86683697 failed with response_code=403
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/backends/file_manager.py:210, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     209 try:
# --> 210     file = self._cache[self._key]
#     211 except KeyError:
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x1656b2ee0>, ('https://app-cirrus-v1-prod-data-1wwdl16p0mm9j.s3.us-west-2.amazonaws.com/starfm_predictions_modis_landsat/2020/15TVG_pred_20200830_from_20200827_using_MODIS_Landsat/15TVG_pred_20200830_from_20200827_using_MODIS_Landsat.tif?X-Amz-Expires=86400&X-STAC-User=Tyler.Cruickshank%40colorado.edu&X-Amz-Security-Token=IQoJb3JpZ2luX2VjELL%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJHMEUCICIWZraqla%2F2%2F%2FprjZX%2F4eHD%2FCS3WP90JZ7%2Fla%2B7KuqoAiEAlkaVjBbGji1%2B2dXt8hPXh1RQBXGgbKyqf11V7tvuqVAqlgMIq%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARABGgw3NTI4Mjc3MDAxMjQiDHBP4O3MzwuH7alMqCrqAuxBfoeRe5Kuyww2fDO1Vryz6DkY96xqN9k3vDy%2FoW%2Fi97RgeYJa%2Fw02YEe9TxDljsBAWxGFjsLoCxsaokDA%2BF8%2B64XN5jXwrwS25eCqIbVbcMbHkmDHIQr8Shc5VnPsmL4pKX3qLIa6O%2FPqdvBAJGuSo4Wnas0rU6e1PP60EtRxQw9%2FLNVXbSuq%2F8hl9%2BXIyBuXdLbtK3XtFR4lKWl7MyFR8GCN8CGS8IOXp8d8ffuDpDkpzOLjgU5OQRnIpXZiGQ53YktnxxcxSwG1x7Dnf3dbje2pBqLvP3uMxSjxxs1baAT5pgcxbg7T2P2g%2FJ80VQaBKL3nkuexsSe9TlyhA1FBf2Z5OFlB9RzsUFJil8jaW6ztDmQw3wUXJiQQwrwvtqK1yvip0c4G%2F78daEZyZCbGF6o4UgmHzNE%2FUZ0VAr4n4%2BOErR%2F9%2B2r6pv%2BWci0g9%2FOMFTMPVYea9ufS9RY3KDb3rTJmktUYhh7oMN2Yi6IGOp0BJbjnWsxEYNpJ%2F8akARb3jg6qfYE993SCq2jq%2BAlTiz1WcaJew4j0mJl3SZASiBBARl52KcZxWoCiknoXw4vom1VdppEtGNbkJjccgYn8%2FBlTjURwMHT2zxs2Oh630379gUgROEVVbw4RT09TArhmMWTEwMoSYkRCZZfBpmpCJLBHVnt0cfQ7yyAe3WYfatyjGWljtPLXgkJB6ptZDw%3D%3D&X-Amz-Date=20230421T175329Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIA26SAHCOOKAZN755J%2F20230421%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=1745c5b746df57e4f91b953113b34150b41f1f53a0da4bcc2763f9e4491790db',), 'r', (('sharing', False),), '5706dce3-e6e4-46b1-8949-dfd9dfbb4c68']
#
# During handling of the above exception, another exception occurred:
#
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:308, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:219, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: 403: Send failure: Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[47], line 6
#       3 lst_fil_ds = stacked_lst_da.isel(band=0).sel(x=set_x, y=set_y, method='nearest', tolerance=20)
#       5 # Convert the output to a dataframe.
# ----> 6 lst_fil_df = lst_fil_ds.to_dataframe(name='lst')
#       8 # Set the index/data to a date format that will be consistent with reindexing below given
#       9 # a range of dates.
#      10 lst_fil_df.index = pd.to_datetime(lst_fil_df.index).date
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/dataarray.py:3757, in DataArray.to_dataframe(self, name, dim_order)
#    3754 else:
#    3755     ordered_dims = ds._normalize_dim_order(dim_order=dim_order)
# -> 3757 df = ds._to_dataframe(ordered_dims)
#    3758 df.columns = [name if c == unique_name else c for c in df.columns]
#    3759 return df
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/dataset.py:6180, in Dataset._to_dataframe(self, ordered_dims)
#    6178 def _to_dataframe(self, ordered_dims: Mapping[Any, int]):
#    6179     columns = [k for k in self.variables if k not in self.dims]
# -> 6180     data = [
#    6181         self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#    6182         for k in columns
#    6183     ]
#    6184     index = self.coords.to_index([*ordered_dims])
#    6185     return pd.DataFrame(dict(zip(columns, data)), index=index)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/dataset.py:6181, in <listcomp>(.0)
#    6178 def _to_dataframe(self, ordered_dims: Mapping[Any, int]):
#    6179     columns = [k for k in self.variables if k not in self.dims]
#    6180     data = [
# -> 6181         self._variables[k].set_dims(ordered_dims).values.reshape(-1)
#    6182         for k in columns
#    6183     ]
#    6184     index = self.coords.to_index([*ordered_dims])
#    6185     return pd.DataFrame(dict(zip(columns, data)), index=index)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/variable.py:607, in Variable.values(self)
#     604 @property
#     605 def values(self):
#     606     """The variable's data as a numpy.ndarray"""
# --> 607     return _as_array_or_item(self._data)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/variable.py:309, in _as_array_or_item(data)
#     295 def _as_array_or_item(data):
#     296     """Return the given values as a numpy array, or as an individual item if
#     297     it's a 0d datetime64 or timedelta64 array.
#     298
#    (...)
#     307     TODO: remove this (replace with np.asarray) once these issues are fixed
#     308     """
# --> 309     data = np.asarray(data)
#     310     if data.ndim == 0:
#     311         if data.dtype.kind == "M":
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/array/core.py:1701, in Array.__array__(self, dtype, **kwargs)
#    1700 def __array__(self, dtype=None, **kwargs):
# -> 1701     x = self.compute()
#    1702     if dtype and x.dtype != dtype:
#    1703         x = x.astype(dtype)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/local.py:319, in reraise(exc, tb)
#     317 if exc.__traceback__ is not tb:
#     318     raise exc.with_traceback(tb)
# --> 319 raise exc
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/local.py:224, in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/core.py:119, in _execute_task(arg, cache, dsk)
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/dask/array/core.py:126, in getter(a, b, asarray, lock)
#     121     # Below we special-case `np.matrix` to force a conversion to
#     122     # `np.ndarray` and preserve original Dask behavior for `getter`,
#     123     # as for all purposes `np.matrix` is array-like and thus
#     124     # `is_arraylike` evaluates to `True` in that case.
#     125     if asarray and (not is_arraylike(c) or isinstance(c, np.matrix)):
# --> 126         c = np.asarray(c)
#     127 finally:
#     128     if lock:
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/indexing.py:483, in ImplicitToExplicitIndexingAdapter.__array__(self, dtype)
#     482 def __array__(self, dtype: np.typing.DTypeLike = None) -> np.ndarray:
# --> 483     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/indexing.py:486, in ImplicitToExplicitIndexingAdapter.get_duck_array(self)
#     485 def get_duck_array(self):
# --> 486     return self.array.get_duck_array()
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/indexing.py:663, in CopyOnWriteArray.get_duck_array(self)
#     662 def get_duck_array(self):
# --> 663     return self.array.get_duck_array()
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/indexing.py:550, in LazilyIndexedArray.get_duck_array(self)
#     549 def get_duck_array(self):
# --> 550     array = self.array[self.key]
#     551     # self.array[self.key] is now a numpy array when
#     552     # self.array is a BackendArray subclass
#     553     # and self.key is BasicIndexer((slice(None, None, None),))
#     554     # so we need the explicit check for ExplicitlyIndexed
#     555     if isinstance(array, ExplicitlyIndexed):
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/rioxarray/_io.py:453, in RasterioArrayWrapper.__getitem__(self, key)
#     452 def __getitem__(self, key):
# --> 453     return indexing.explicit_indexing_adapter(
#     454         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     455     )
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/core/indexing.py:857, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     835 """Support explicit indexing by delegating to a raw indexing method.
#     836
#     837 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#     854 Indexing result, in the form of a duck numpy-array.
#     855 """
#     856 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 857 result = raw_indexing_method(raw_key.tuple)
#     858 if numpy_indices.tuple:
#     859     # index the loaded np.ndarray
#     860     result = NumpyIndexingAdapter(result)[numpy_indices]
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/rioxarray/_io.py:428, in RasterioArrayWrapper._getitem(self, key)
#     425 else:
#     426     with self.lock:
#     427         riods = _ensure_warped_vrt(
# --> 428             self.manager.acquire(needs_lock=False), self.vrt_params
#     429         )
#     430         out = riods.read(band_key, window=window, masked=self.masked)
#     431         if self._unsigned_dtype is not None:
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/backends/file_manager.py:192, in CachingFileManager.acquire(self, needs_lock)
#     177 def acquire(self, needs_lock=True):
#     178     """Acquire a file object from the manager.
#     179
#     180     A new file is only opened if it has expired from the
#    (...)
#     190         An open file object, as returned by ``opener(*args, **kwargs)``.
#     191     """
# --> 192     file, _ = self._acquire_with_cache_info(needs_lock)
#     193     return file
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/xarray/backends/file_manager.py:216, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     214     kwargs = kwargs.copy()
#     215     kwargs["mode"] = self._mode
# --> 216 file = self._opener(*self._args, **kwargs)
#     217 if self._mode == "w":
#     218     # ensure file doesn't get overridden when opened again
#     219     self._mode = "a"
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/rasterio/env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File /opt/miniconda3/envs/hydrosat/lib/python3.9/site-packages/rasterio/__init__.py:304, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     301 path = _parse_path(raw_dataset_path)
#     303 if mode == "r":
# --> 304     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     305 elif mode == "r+":
#     306     dataset = get_writer_for_path(path, driver=driver)(
#     307         path, mode, driver=driver, sharing=sharing, **kwargs
#     308     )
#
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: 403: Send failure: Broken pipe
# ERROR 1: Request for 59694248-61101602 failed with response_code=403
# ERROR 1: Request for 63473171-64892995 failed with response_code=403
# ERROR 1: Request for 67256709-68670129 failed with response_code=403
# ERROR 1: Request for 71025244-72434372 failed with response_code=403
# ERROR 1: Request for 74804719-76211192 failed with response_code=403
# ERROR 1: Request for 78586072-79992814 failed with response_code=403
# ERROR 1: Request for 82370769-83780005 failed with response_code=403
# ERROR 1: Request for 86148315-86683697 failed with response_code=403
# ERROR 1: TIFFFillTile:Read error at row 3840, col 3840, tile 184; got 0 bytes, expected 177936
# ERROR 1: TIFFReadEncodedTile() failed.
# ERROR 1: IReadBlock failed at X offset 8, Y offset 8: TIFFReadEncodedTile() failed.
# ERROR 1: Request for 62125091-63589587 failed with response_code=403
# ERROR 1: Request for 66049128-67509786 failed with response_code=403
# ERROR 1: Request for 69976512-71431849 failed with response_code=403
# ERROR 1: Request for 73903719-75360811 failed with response_code=403
# ERROR 1: Request for 77848557-79303228 failed with response_code=403
# ERROR 1: Request for 81787704-83241678 failed with response_code=403
# ERROR 1: Request for 85716826-87184723 failed with response_code=403
# ERROR 1: Request for 89654453-89842878 failed with response_code=403
# ERROR 1: Request for 62125091-63589587 failed with response_code=403
# ERROR 1: Request for 66049128-67509786 failed with response_code=403
# ERROR 1: Request for 69976512-71431849 failed with response_code=403
# ERROR 1: Request for 73903719-75360811 failed with response_code=403
# ERROR 1: Request for 77848557-79303228 failed with response_code=403
# ERROR 1: Request for 81787704-83241678 failed with response_code=403
# ERROR 1: Request for 85716826-87184723 failed with response_code=403
# ERROR 1: Request for 89654453-89842878 failed with response_code=403
# ERROR 1: TIFFFillTile:Read error at row 3840, col 3840, tile 184; got 0 bytes, expected 183431
# ERROR 1: TIFFReadEncodedTile() failed.
# ERROR 1: IReadBlock failed at X offset 8, Y offset 8: TIFFReadEncodedTile() failed.
# ERROR 1: Request for 60954123-62388002 failed with response_code=403
# ERROR 1: Request for 64792735-66239360 failed with response_code=403
# ERROR 1: Request for 68639833-70072131 failed with response_code=403
# ERROR 1: Request for 72472876-73898532 failed with response_code=403
# ERROR 1: Request for 76321508-77753703 failed with response_code=403
# ERROR 1: Request for 80186123-81624295 failed with response_code=403
# ERROR 1: Request for 84048798-85493642 failed with response_code=403
# ERROR 1: Request for 87912756-88276570 failed with response_code=403
# ERROR 1: Request for 60954123-62388002 failed with response_code=403
# ERROR 1: Request for 64792735-66239360 failed with response_code=403
# ERROR 1: Request for 68639833-70072131 failed with response_code=403
# ERROR 1: Request for 72472876-73898532 failed with response_code=403
# ERROR 1: Request for 76321508-77753703 failed with response_code=403
# ERROR 1: Request for 80186123-81624295 failed with response_code=403
# ERROR 1: Request for 84048798-85493642 failed with response_code=403
# ERROR 1: Request for 87912756-88276570 failed with response_code=403
# ERROR 1: TIFFFillTile:Read error at row 3840, col 3840, tile 184; got 0 bytes, expected 183170
# ERROR 1: TIFFReadEncodedTile() failed.
# ERROR 1: IReadBlock failed at X offset 8, Y offset 8: TIFFReadEncodedTile() failed.

# %% [markdown]
# #### Get min, max, mean LST from the AOI

# %%
# NOT DONE YET
# 
# lst_min_fil_ds = LST_filtered.ds.isel(band=0).min()

lst_min_fil_ds.values
# Out:
# array(188.95126, dtype=float32)

# %% [markdown]
# #### Merge LST and 2mT dataframes & plot.

# %%
# Merge LST and 2mT dataframes into one larger one.
lst_2mT_df = temp_2m_df.join(lst_df)

# Dont need these two duplicate columns.
lst_2mT_df.drop(['date', 'index'], axis=1, inplace=True)

# Now plot LST and 2mT ----------------------
ax = (plt.plot(lst_2mT_df['time'], lst_2mT_df['lst'], label='Fusion LST', marker='o', c='m',))# figsize=(12,7)))
ax = (plt.plot(lst_2mT_df['time'], lst_2mT_df['t2m'], label='HRRR 2mT', marker='s', c='b',))

plt.title(f'Fused LST and 2m HRRR Temperature')
plt.grid(True)
plt.ylabel('Temperature [K]')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# #### Calculate CATD and add it to dataframe with LST and 2mT.

# %%
# Use the pandas .sub() function to subtract 2mT from LST.
# A fill value can be added for dates where LST is not available.
lst_2mT_df['catd'] = lst_2mT_df['lst'].sub(lst_2mT_df['t2m'])

# Plot ------------------------
ax = (plt.plot(lst_2mT_df['time'], lst_2mT_df['catd'], label='CATD', marker='o', c='m',))

plt.title('CATD (LST - HRRR 2mT)')
plt.grid(True)
plt.ylabel('CATD')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### Compute SENTINEL2 NDVI.

# %%
s2_ndvi_ts = (np.array(s2_nir_ts) - np.array(s2_red_ts)) / (np.array(s2_nir_ts) + np.array(s2_nir_ts))

# Convert to a dataframe.
s2_ndvi_df = pd.DataFrame({'ndvi': s2_ndvi_ts,
                          'datetime': pd.to_datetime(s2_dt)}).sort_values(by='datetime')

# Get the date in the correct/consistent format.
s2_ndvi_df['date'] = [t.to_pydatetime().strftime('%Y-%m-%d') for t in s2_ndvi_df['datetime']]

# Reset the index.
s2_ndvi_df = fill_in_missing_dates('2020-04-01', '2020-10-30', s2_ndvi_df)
s2_ndvi_df['color'] = 'red'
s2_ndvi_df

# %% [markdown]
# ### Plot sentinel2 NDVI.

# %%
# Plot just the SENTINEL2 NDVI.
fig, ax = plt.subplots()

for i in s2_ndvi_df.color.unique():
    df_color = s2_ndvi_df[s2_ndvi_df.color==i]
    df_color.plot.scatter(x='datetime', y='ndvi', ax=ax, c=i, label=df_color.color.iloc[0],
                         grid=True, alpha=0.6, figsize=(12,7))


ax.set_title('Ames, IA SENTINEL2 NDVI')
plt.legend('S2-median composite NDVI')

# %% [markdown]
# ### Merge NDVI into the dataframe holding LST, 2mT, and CATD.

# %%
# Merge NDVI with catd dataframes into one larger one.
catd_ndvi_df = lst_2mT_df.join(s2_ndvi_df)
catd_ndvi_df

# %% [markdown]
# ### Plot CATD and NDVI.

# %%
# Plot CATD and NDVI on twin axis ------------------------

fig, ax1 = plt.subplots(figsize=(9, 6))

# Instantiate a second axes that shares the same x-axis
ax2 = ax1.twinx()  

ax1.plot(catd_ndvi_df['time'], catd_ndvi_df['ndvi'], label='NDVI', marker='s', c='b')
ax2.plot(catd_ndvi_df['time'], catd_ndvi_df['catd'], label='CATD', marker='o', c='r',)

ax1.set_ylim(.30, .50)
ax2.set_ylim(25, -25)

ax1.set_ylabel("Sentinel2 NDVI", color='blue', fontsize=14)
ax2.set_ylabel("CATD", color='red', fontsize=14)

plt.title('CATD & NDVI')
plt.grid(True)

ax1.legend()
ax2.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 8
#       5 # Instantiate a second axes that shares the same x-axis
#       6 ax2 = ax1.twinx()
# ----> 8 ax1.plot(catd_ndvi_df['time'], catd_ndvi_df['ndvi'], label='NDVI', marker='s', c='b')
#       9 ax2.plot(catd_ndvi_df['time'], catd_ndvi_df['catd'], label='CATD', marker='o', c='r',)
#      11 ax1.set_ylim(.30, .50)
#
# NameError: name 'catd_ndvi_df' is not defined

# %% [markdown]
# #### Plot rolling avergae CATD and NDVI

# %%
# Compute 5-day rolling CATD average.


# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 5
catd_ndvi_df['catd_sma5'] = catd_ndvi_df['catd'].rolling(5).mean()

# Plot CATD and NDVI on twin axis ------------------------
fig, ax1 = plt.subplots(figsize=(9, 6))

# Instantiate a second axes that shares the same x-axis
ax2 = ax1.twinx()  

ax1.plot(catd_ndvi_df['time'], catd_ndvi_df['ndvi'], label='NDVI', marker='s', c='b')
ax2.plot(catd_ndvi_df['time'], catd_ndvi_df['catd_sma5'], label='CATD SMA5', marker='o', c='r',)

ax1.set_ylim(.30, .50)
ax2.set_ylim(25, -25)

ax1.set_ylabel("Sentinel2 NDVI", color='red', fontsize=14)
ax2.set_ylabel("CATD SMA5", color='blue', fontsize=14)

plt.title('CATD SMA5 & NDVI')
plt.grid(True)

ax1.legend()
ax2.legend()
plt.show()
